# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import requests
import re
driver = webdriver.Chrome(r'C:\Users\nilsi\Desktop\Project\chromedriver') 
import selenium as SN
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nilsi\\Desktop\\Project'

# %%
def getPcode(page):
    pCodeList = []
    for i in range(1,page+1):
        print(i,"페이지 입니다")
        headers = {"Referer" : "http://prod.danawa.com/list/?cate=112758&15main_11_02",
               "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36"}

        params = {"page" : page, "listCategoryCode" : 758, "categoryCode" : 758, "physicsCate1":860, 
                  "physicsCate2":869,"physicsCate3":0, "physicsCate4":0, "viewMethod": "LIST", "sortMethod":"",
                  "listCount":30, "group": 11, "depth": 2, "brandName":"","makerName":"","searchOptionName":"",
                  "sDiscountProductRate":0, "sInitialPriceDisplay":"N", 
                  "sPowerLinkKeyword":"노트북", "oCurrentCategoryCode":"a:2:{i:1;i:96;i:2;i:758;}", 
                  "innerSearchKeyword":"",
                  "listPackageType":1, "categoryMappingCode":710, "priceUnit":0, "priceUnitValue":0, "priceUnitClass":"",
                  "cmRecommendSort":"N", "cmRecommendSortDefault":"N", "bundleImagePreview":"N", "nPackageLimit":5, 
                  "nPriceUnit":0,"bMakerDisplayYN":"Y","isDpgZoneUICategory": "N", "sProductListApi":"search"}

        res = requests.post("http://prod.danawa.com/list/ajax/getProductList.ajax.php", headers = headers, data=params)
        soup = BeautifulSoup(res.text, "html.parser")
        a = soup.findAll("a", attrs = {"name":"productName"})
        
        for i in range(len(a)):
            pCodeList.append(a[i]['href'][35:-12])

        time.sleep(crawl_delay-8)

        
        
    return pCodeList

# %%
#pcode=getPcode(100)
pcode=getPcode(150)
# Out:
# 1 페이지 입니다
# 2 페이지 입니다
# 3 페이지 입니다
# 4 페이지 입니다
# 5 페이지 입니다
# 6 페이지 입니다
# 7 페이지 입니다
# 8 페이지 입니다
# 9 페이지 입니다
# 10 페이지 입니다
# 11 페이지 입니다
# 12 페이지 입니다
# 13 페이지 입니다
# 14 페이지 입니다
# 15 페이지 입니다
# 16 페이지 입니다
# 17 페이지 입니다
# 18 페이지 입니다
# 19 페이지 입니다
# 20 페이지 입니다
# 21 페이지 입니다
# 22 페이지 입니다
# 23 페이지 입니다
# 24 페이지 입니다
# 25 페이지 입니다
# 26 페이지 입니다
# 27 페이지 입니다
# 28 페이지 입니다
# 29 페이지 입니다
# 30 페이지 입니다
# 31 페이지 입니다
# 32 페이지 입니다
# 33 페이지 입니다
# 34 페이지 입니다
# 35 페이지 입니다
# 36 페이지 입니다
# 37 페이지 입니다
# 38 페이지 입니다
# 39 페이지 입니다
# 40 페이지 입니다
# 41 페이지 입니다
# 42 페이지 입니다
# 43 페이지 입니다
# 44 페이지 입니다
# 45 페이지 입니다
# 46 페이지 입니다
# 47 페이지 입니다
# 48 페이지 입니다
# 49 페이지 입니다
# 50 페이지 입니다
# 51 페이지 입니다
# 52 페이지 입니다
# 53 페이지 입니다
# 54 페이지 입니다
# 55 페이지 입니다
# 56 페이지 입니다
# 57 페이지 입니다
# 58 페이지 입니다
# 59 페이지 입니다
# 60 페이지 입니다
# 61 페이지 입니다
# 62 페이지 입니다
# 63 페이지 입니다
# 64 페이지 입니다
# 65 페이지 입니다
# 66 페이지 입니다
# 67 페이지 입니다
# 68 페이지 입니다
# 69 페이지 입니다
# 70 페이지 입니다
# 71 페이지 입니다
# 72 페이지 입니다
# 73 페이지 입니다
# 74 페이지 입니다
# 75 페이지 입니다
# 76 페이지 입니다
# 77 페이지 입니다
# 78 페이지 입니다
# 79 페이지 입니다
# 80 페이지 입니다
# 81 페이지 입니다
# 82 페이지 입니다
# 83 페이지 입니다
# 84 페이지 입니다
# 85 페이지 입니다
# 86 페이지 입니다
# 87 페이지 입니다
# 88 페이지 입니다
# 89 페이지 입니다
# 90 페이지 입니다
# 91 페이지 입니다
# 92 페이지 입니다
# 93 페이지 입니다
# 94 페이지 입니다
# 95 페이지 입니다
# 96 페이지 입니다
# 97 페이지 입니다
# 98 페이지 입니다
# 99 페이지 입니다
# 100 페이지 입니다
# 101 페이지 입니다
# 102 페이지 입니다
# 103 페이지 입니다
# 104 페이지 입니다
# 105 페이지 입니다
# 106 페이지 입니다
# 107 페이지 입니다
# 108 페이지 입니다
# 109 페이지 입니다
# 110 페이지 입니다
# 111 페이지 입니다
# 112 페이지 입니다
# 113 페이지 입니다
# 114 페이지 입니다
# 115 페이지 입니다
# 116 페이지 입니다
# 117 페이지 입니다
# 118 페이지 입니다
# 119 페이지 입니다
# 120 페이지 입니다
# 121 페이지 입니다
# 122 페이지 입니다
# 123 페이지 입니다
# 124 페이지 입니다
# 125 페이지 입니다
# 126 페이지 입니다
# 127 페이지 입니다
# 128 페이지 입니다
# 129 페이지 입니다
# 130 페이지 입니다
# 131 페이지 입니다
# 132 페이지 입니다
# 133 페이지 입니다
# 134 페이지 입니다
# 135 페이지 입니다
# 136 페이지 입니다
# 137 페이지 입니다
# 138 페이지 입니다
# 139 페이지 입니다
# 140 페이지 입니다
# 141 페이지 입니다
# 142 페이지 입니다
# 143 페이지 입니다
# 144 페이지 입니다
# 145 페이지 입니다
# 146 페이지 입니다
# 147 페이지 입니다
# 148 페이지 입니다
# 149 페이지 입니다
# 150 페이지 입니다

# %%
len(pcode)
# Out:
# 4500

# %% [markdown]
# pcode=['7405087']

# %% [markdown]
# pcode=['7405087',
#  '6953572',
#  '8100319',
#  '7422247',
#  '8992124',
#  '7945261']

# %% [markdown]
# dd=pd.DataFrame(pcode)

# %% [markdown]
# dd.to_csv('pcode.csv')

# %%
crawl_delay=12

codeDB = {'LG울트라':9293607, '레노보LEGION':8097724,'한성올데이':9261852,'에이서니트로':8992124,'삼전노트북':7051246} #{key:value} = {car name : car id}
carDB = {} #where the result data stores

# %%
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(3) # 웹 자원이 로드되기까지의 대기 시간 지정

driver.get('http://prod.danawa.com/info/?pcode='+str(5359371)+'&cate=112758#bookmark_product_information')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
printTable = soup.find('div',{'class':'lowest_area'}) #가격 표 따오기

# %%
    
    printTable = re.sub('<.+?>','\n',str(printTable)).strip()
    printTable = [line.replace('\n','').replace('←','') for line in printTable.split('\n\n\n\n\n')]
    printTable = [line.split('  ') for line in printTable]
    printTable = [[j.strip() for j in i] for i in printTable][3::]

# %%
def get_raw_laptop_table(pcode):
    driver = webdriver.Chrome('./chromedriver')
    driver.implicitly_wait(3) # 웹 자원이 로드되기까지의 대기 시간 지정

    driver.get('http://prod.danawa.com/info/?pcode='+str(pcode)+'&cate=112758#bookmark_product_information')
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    printTable = soup.find('div',{'class':'prod_spec'}) #스펙 표만 따오기
    printTable2 = soup.find('tbody',{'class':'high_list'}) #가격 표 따오기

    
    driver.close()
    
    printTable = re.sub('<.+?>','\n',str(printTable)).strip()
    printTable = [line.replace('\n','').replace('←','') for line in printTable.split('\n\n\n\n\n')]
    printTable = [line.split('  ') for line in printTable]
    printTable = [[j.strip() for j in i] for i in printTable][3::] 
    
    printTable2 = re.sub('<.+?>','\n',str(printTable2)).strip()
    printTable2 = [line.replace('\n','').replace('←','') for line in printTable2.split('\n\n\n\n\n')]
    printTable2 = [line.split('  ') for line in printTable2]
    printTable2 = [[j.strip() for j in i] for i in printTable2][3::]#기본적인 가공만 마침(공백과 같은 불량한 데이터가 섞여있다)

    return printTable, printTable2

# %%
#remove_empty 함수
def remove_empty(data):
    data = [item for sublist in data for item in sublist]
    for i in range(len(data)+50):
        try:
            if (data[i] =='' and data[i+1]=='' and data[i+2]==''):
                del data[i],data[i],data[i]
            elif (data[i] =='' and data[i+1]==''):
                del data[i],data[i]
            elif data[i] =='':
                del data[i]
                
        except IndexError : 
            continue
        
    data = [w.replace('(\t\t\t\t\t\t\t제조사 웹사이트 바로가기)\t\t\t\t\t\t\t\t\t\t\t\t', '') for w in data]
    data[1] = data[1].split(' ',1)
    data[1] = data[1][0] 
    
    # 메모리 특징과 HDD 특징이 붙어 있기 때문에 이를 분리해주는 코드 
    index = [i for i, s in enumerate(data) if 'HDD 특징' in s]  #HDD 특징이라는 스트링을 포함하는 원소의 인덱스를 추출
    data[index[0]:index[0]+1] = data[int(index[0])].split(' ',1) #쪼갠 결과를 줄줄이 붙이기
    
    index2 = [i for i, s in enumerate(data) if 'VRAM' in s]  #VRAM이라는 스트링을 포함하는 원소의 인덱스를 추출
    data[index2[0]:index2[0]+1] = data[int(index2[0])].split(' ',1) #쪼갠 결과를 줄줄이 붙이기, split함수의 1이라는 인자는 1개까지만 쪼개라는 의미
    
    index3 = [i for i, s in enumerate(data) if 'Kg' or 'g' in s]  #Kg이라는 스트링을 포함하는 원소의 인덱스를 추출
    data[index3[0]:index3[0]+1] = data[int(index3[0])].split(' ',1) #쪼갠 결과를 줄줄이 붙이기, split함수의 1이라는 인자는 1개까지만 쪼개라는 의미
    
    
    
    
    return data

# %%
def spec_to_dataframe(data):
    data.remove('디스플레이')
    data_index=data.index('디스플레이 특징')
    new_list=data[0:data_index]
    new_list[9:10]=new_list[9].split(' ',1)
    new_list.insert(10,'CPU클럭')
    
    data_index=data.index('메모리 용량')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == '메모리 타입':
        new_list[-1] = '0'
    
    data_index=data.index('메모리 타입')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == 'HDD 특징':
        new_list[-1] = '0'
    
    data_index=data.index('HDD 용량')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == 'SSD 형태':
        new_list[-1] = '0'
    
    data_index=data.index('SSD 용량')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] =='스토리지 구성' :
        new_list[-1] = '0'
   
    data_index=data.index('GPU 종류')
    len_data=len(new_list)
    new_list[len_data:len_data+2]=(data[data_index+1:data_index+3])
    if new_list[-1] == '엔비디아':
        new_list[len_data+1]=(data[data_index+3])
        if new_list[-1] == 'AMD':
            new_list[len_data+1] =(data[data_index+4])

    data_index=data.index('VGA 메모리')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] =='GPU 특징' :
        new_list[-1] = '0'
        
    data_index=data.index('배터리')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == '어댑터':
        new_list[-1] = '0'
        
    data_index=data.index('운영체제')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == '제원':
        new_list[-1] = '없음'
        
    
    data_index=data.index('무게')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == 'A/S 특징':
        new_list[-1] = '0'
    
    data_index=data.index('보증기간')
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == '용도':
        new_list[-1] = '0'
        
    try: data_index=data.index('두께')
    except ValueError:
        len_data=len(new_list)
        new_list[len_data:len_data+1]=['두께','0']
        
        
    len_data=len(new_list)
    new_list[len_data:len_data+1]=(data[data_index:data_index+2])
    if new_list[-1] == '무게':
        new_list[-1] = '0'
        
    list_col = new_list[0::2]
    list_ele = new_list[1::2]
    
    DF= pd.DataFrame(list(zip(list_col, list_ele)), 
               columns =['Name', 'Val']) 
        
    return DF.T

# %%
df=pd.DataFrame()
for p in range(len(pcode)) :
    
    table = get_raw_laptop_table(pcode[p])
    
    price_1 = [item for sublist in table[1] for item in sublist]
    price_index=[i for i, s in enumerate(price_1) if '원' in s]
    price = price_1[price_index[0]]

    table = remove_empty(table[0])
    table = spec_to_dataframe(table)
    table.loc[:,21] = pd.Series(price,index=table.index)
    table[21]['Name']='가격'
    df=df.append(table.iloc[1,:])
    if p % 10 ==0:
        print(p)
    time.sleep(crawl_delay)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-251-7f4fac243bb1> in <module>
#       6     price_1 = [item for sublist in table[1] for item in sublist]
#       7     price_index=[i for i, s in enumerate(price_1) if '원' in s]
# ----> 8     price = price_1[price_index[0]]
#       9
#      10     table = remove_empty(table[0])
#
# IndexError: list index out of range

# %%
pcode[0]
# Out:
# '5359371'

# %% [markdown]
# table = get_raw_laptop_table(9293607)
# price_1 = [item for sublist in table[1] for item in sublist]
# price_index=[i for i, s in enumerate(price_1) if '원' in s]
# price = price_1[price_index[0]]

# %% [markdown]
# table = remove_empty(table[0])
# table = spec_to_dataframe(table)
# table.loc[:,21] = pd.Series(price,index=table.index)
# table[21]['Name']='가격'
# df=df.append(table.iloc[1,:])
# print(p)
# time.sleep(crawl_delay)

# %%
df.iloc[:,4:]
# Out:
#             4               5      6                7          8   \
# Val   i7-9750H  2.6GHz(4.5GHz)  헥사 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i3-7100U        (2.4GHz)  듀얼 코어  33.78cm(13.3인치)   와이드 16:9
# Val   i5-8265U  1.6GHz(3.9GHz)  쿼드 코어  33.78cm(13.3인치)   와이드 16:9
# Val   i5-8250U  1.6GHz(3.4GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val      4415U        (2.3GHz)  듀얼 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i5-8250U  1.6GHz(3.4GHz)  쿼드 코어  33.78cm(13.3인치)   와이드 16:9
# Val   i7-8565U  1.8GHz(4.6GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val    i3-8100        (3.6GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i7-8565U  1.8GHz(4.6GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i5-8300H  2.3GHz(4.0GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val    E-2176M        (2.7GHz)  헥사 코어  43.94cm(17.3인치)   와이드 16:9
# Val   i3-8145U  2.1GHz(3.9GHz)  듀얼 코어    35.56cm(14인치)   와이드 16:9
# Val   i7-8565U  1.8GHz(4.6GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val  i5-7300HQ  2.5GHz(3.5GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i5-8265U  1.6GHz(3.9GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i5-8265U  1.6GHz(3.9GHz)  쿼드 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i7-8750H  2.2GHz(4.1GHz)  헥사 코어  39.62cm(15.6인치)   와이드 16:9
# Val   i7-8750H  2.2GHz(4.1GHz)  헥사 코어  43.94cm(17.3인치)   와이드 16:9
# Val       VRAM:2GB   52.5Wh  운영체제 미포함  1.69Kg A/S 특징  1년   두께:17.9mm
# Val       VRAM:4GB     43Wh     윈도우10  2.38Kg A/S 특징  1년   두께:28.2mm
# Val  VRAM:시스템메모리공유     82Wh  운영체제 미포함   1.6Kg A/S 특징   0   두께:15.9mm
# Val       VRAM:2GB   52.5Wh     윈도우10  1.69Kg A/S 특징  1년   두께:17.9mm
# Val       VRAM:6GB  46.74Wh  운영체제 미포함   2.0Kg A/S 특징  1년     두께:23mm
# Val       VRAM:8GB     82Wh     윈도우10  2.25Kg A/S 특징  2년  두께:18.95mm
# Val       VRAM:6GB     82Wh  운영체제 미포함   2.2Kg A/S 특징  1년  두께:18.95mm
# Val       VRAM:6GB     51Wh  운영체제 미포함   2.3Kg A/S 특징  1년   두께:29.5mm
# Val       VRAM:4GB     47Wh  운영체제 미포함  2.34Kg A/S 특징  1년   두께:31.7mm
# Val  VRAM:시스템메모리공유     75Wh     윈도우10  1.25Kg A/S 특징  1년   두께:15.4mm
# Val       VRAM:8GB     51Wh  운영체제 미포함  2.49Kg A/S 특징  1년   두께:29.5mm
# Val  VRAM:시스템메모리공유     43Wh       리눅스   1.9Kg A/S 특징  1년   두께:19.6mm
# Val  VRAM:시스템메모리공유     45Wh     윈도우10  1.65Kg A/S 특징  1년   두께:17.9mm
# Val       VRAM:2GB     50Wh     윈도우10  1.19Kg A/S 특징  1년   두께:15.9mm
# Val  VRAM:시스템메모리공유     43Wh       리눅스   1.9Kg A/S 특징  1년   두께:19.9mm
# Val  VRAM:시스템메모리공유     36Wh  운영체제 미포함  1.39Kg A/S 특징  1년   두께:22.4mm
# Val       VRAM:2GB     50Wh  운영체제 미포함  1.19Kg A/S 특징  1년   두께:15.9mm
# Val  VRAM:시스템메모리공유        0  윈도우10 프로  1.35Kg A/S 특징  1년   두께:16.7mm
# Val       VRAM:6GB     57Wh  운영체제 미포함   2.4Kg A/S 특징  1년     두께:26mm
# Val  VRAM:시스템메모리공유     39Wh     윈도우10    995g A/S 특징  1년   두께:16.5mm
# Val  VRAM:시스템메모리공유     75Wh       리눅스    995g A/S 특징  1년   두께:14.9mm
# Val  VRAM:시스템메모리공유     43Wh       리눅스   1.9Kg A/S 특징  1년   두께:19.6mm
# Val  VRAM:시스템메모리공유     44Wh  운영체제 미포함  1.97Kg A/S 특징  1년     두께:22mm
# Val       VRAM:4GB     72Wh  운영체제 미포함  1.95Kg A/S 특징  1년   두께:19.9mm
#
#                 21
# Val              최
# Val              최
# Val              1
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              현
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val              최
# Val  최저가1,690,000원
